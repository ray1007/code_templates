# %% [markdown]
# <a href="https://colab.research.google.com/github/ray1007/code_templates/blob/master/python/pytorch_templates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## This is my pytorch template.
# let's cover simple DNN, convNet, BiLSTM, BiLSTM-CRF here.
